# %%
import numpy as np
import pandas as pd
import os
from PIL import Image
from collections import Counter

# %% [markdown]
# # Load CSV

# %%
path = 'data/udacity-object-dataset/'

# %%
df = pd.read_csv(os.path.join(path, 'labels.csv'), sep=' ', header=None, 
                 names=['filename', 'xmin', 'ymin', 'xmax', 'ymax', 'occluded', 'label', 'attributes'])

# %%
df.head(20)
# Out:
#                    filename  xmin  ymin  xmax  ymax  occluded       label  \
# 0   1478019952686311006.jpg   950   574  1004   620         0         car
# 1   1478019952686311006.jpg  1748   482  1818   744         0  pedestrian
# 2   1478019953180167674.jpg   872   586   926   632         0         car
# 3   1478019953689774621.jpg   686   566   728   618         1       truck
# 4   1478019953689774621.jpg   716   578   764   622         0         car
# 5   1478019953689774621.jpg   826   580   880   626         0         car
# 6   1478019953689774621.jpg  1540   488  1680   608         1         car
# 7   1478019953689774621.jpg  1646   498  1848   594         1         car
# 8   1478019954186238236.jpg   662   562   710   616         1       truck
# 9   1478019954186238236.jpg   686   576   730   628         0         car
# 10  1478019954186238236.jpg   802   582   856   628         0         car
# 11  1478019954186238236.jpg  1448   474  1722   596         1         car
# 12  1478019954186238236.jpg  1732   498  1918   594         1         car
# 13  1478019954685370994.jpg   640   560   694   614         1       truck
# 14  1478019954685370994.jpg   662   576   708   624         0         car
# 15  1478019954685370994.jpg   776   578   830   624         0         car
# 16  1478019954685370994.jpg  1492   472  1830   608         1         car
# 17  1478019955185244088.jpg   618   558   678   614         1       truck
# 18  1478019955185244088.jpg   640   578   688   620         0         car
# 19  1478019955185244088.jpg   758   570   812   616         0         car
#
#    attributes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %% [markdown]
# # Look at the images

# %%
im = Image.open(path + '1478019952686311006.jpg')

# %%
im_data = np.array(im, dtype=np.uint8)

# %%
im_data.shape
# Out:
# (1200, 1920, 3)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1200 at 0x7F40E7D70550>

# %% [markdown]
# # List of classes

# %%
print(Counter(df['label']))
# Out:
# Counter({'car': 60788, 'trafficLight': 17253, 'pedestrian': 9866, 'truck': 3503, 'biker': 1676})

# %%
classes = list(set(df['label']))
class_ids = {c: i for i, c in enumerate(classes)}

# %%
classes
# Out:
# ['biker', 'trafficLight', 'pedestrian', 'truck', 'car']

# %%
class_ids
# Out:
# {'biker': 0, 'car': 4, 'pedestrian': 2, 'trafficLight': 1, 'truck': 3}

# %% [markdown]
# Save the list of classes to a file

# %%
classes_path = path + 'classes.txt'
with open(classes_path, 'w') as f:
    f.write('\n'.join(classes))

# %% [markdown]
# # Convert the data frame into lists of numpy arrays

# %% [markdown]
# Convert the dataset into two lists:
# - File names of images
# - numpy arrays of boxes
#
# Each image can have 0 or more boxes stored as a numpy array of shape (N, 5). Each row of the array is one box. Columns:
# - class_id int
# - x_min int
# - y_min int
# - x_max int
# - y_max int

# %%
images = []
boxes = []

for filename, df_file in df.groupby(['filename']):
    images.append(filename)
    
    box = []
    for index, row in df_file.iterrows():
        x_min, y_min, x_max, y_max, label = row['xmin'], row['ymin'], row['xmax'], row['ymax'], row['label']
        class_id = class_ids[label]
        
        # Original boxes stored as 1D list of class, x_min, y_min, x_max, y_max.
        box.append(np.array([class_id, x_min, y_min, x_max, y_max], dtype=np.object))
        
    box = np.vstack(box)
    boxes.append(box)

# %%
len(images), len(boxes), images[0], boxes[0].shape
# Out:
# (13063, 13063, '1478019952686311006.jpg', (2, 5))

# %% [markdown]
# # Split into training and validation sets

# %%
train_split = 0.8
train_count = int(len(images) * train_split)

train_images = images[:train_count]
train_boxes = boxes[:train_count]
val_images = images[train_count:]
val_boxes = boxes[train_count:]

# %%
np.random.seed(42)

p = np.random.permutation(len(train_images))
train_images = np.array(train_images)[p]
train_boxes = np.array(train_boxes)[p]

p = np.random.permutation(len(val_images))
val_images = np.array(val_images)[p]
val_boxes = np.array(val_boxes)[p]

# %% [markdown]
# # Save into npz files

# %%
train_path = path + 'train.npz'
val_path = path + 'val.npz'

np.savez(train_path, images=train_images, boxes=train_boxes)
np.savez(val_path, images=val_images, boxes=val_boxes)
